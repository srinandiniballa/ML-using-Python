# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
sns.set(style="dark")

# %%
nn=pd.read_csv("Absenteeism_at_work.csv",sep=";")

# %%
nn.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
# ...

# %%
nn.head(30).style.background_gradient(cmap="Dark2_r")
# Out:
# <style type="text/css">
# #T_8861e_row0_col0, #T_8861e_row0_col3, #T_8861e_row0_col16, #T_8861e_row1_col3, #T_8861e_row1_col13, #T_8861e_row2_col5, #T_8861e_row3_col1, #T_8861e_row4_col0, #T_8861e_row4_col16, #T_8861e_row5_col5, #T_8861e_row6_col0, #T_8861e_row6_col13, #T_8861e_row7_col8, #T_8861e_row8_col0, #T_8861e_row8_col8, #T_8861e_row8_col19, #T_8861e_row9_col13, #T_8861e_row9_col16, #T_8861e_row10_col8, #T_8861e_row11_col3, #T_8861e_row11_col8, #T_8861e_row12_col8, #T_8861e_row13_col5, #T_8861e_row14_col5, #T_8861e_row16_col5, #T_8861e_row17_col5, #T_8861e_row18_col5, #T_8861e_row18_col19, #T_8861e_row19_col16, #T_8861e_row20_col1, #T_8861e_row20_col19, #T_8861e_row21_col5, #T_8861e_row22_col0, #T_8861e_row22_col13, #T_8861e_row23_col8, #T_8861e_row24_col0, #T_8861e_row24_col16, #T_8861e_row25_col0, #T_8861e_row25_col13, #T_8861e_row26_col0, #T_8861e_row26_col3, #T_8861e_row26_col16, #T_8861e_row27_col17, #T_8861e_row28_col0, #T_8861e_row28_col16, #T_8861e_row29_col5 {
# ...

# %%
nn.sample(30).style.background_gradient(cmap="viridis")
# Out:
# <style type="text/css">
# #T_a2634_row0_col0, #T_a2634_row3_col0, #T_a2634_row10_col0 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_a2634_row0_col1, #T_a2634_row23_col1 {
#   background-color: #b8de29;
#   color: #000000;
# }
# #T_a2634_row0_col2, #T_a2634_row19_col2, #T_a2634_row20_col2, #T_a2634_row21_col8 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# ...

# %%
nn.sample(30).style.background_gradient(cmap="plasma")
# Out:
# <style type="text/css">
# #T_ab888_row0_col0 {
#   background-color: #8b0aa5;
#   color: #f1f1f1;
# }
# #T_ab888_row0_col1, #T_ab888_row10_col1, #T_ab888_row25_col1, #T_ab888_row26_col1 {
#   background-color: #ef7c51;
#   color: #f1f1f1;
# }
# #T_ab888_row0_col2, #T_ab888_row8_col2, #T_ab888_row13_col2, #T_ab888_row24_col2 {
#   background-color: #f68d45;
#   color: #f1f1f1;
# }
# #T_ab888_row0_col3, #T_ab888_row0_col13, #T_ab888_row4_col12, #T_ab888_row7_col13, #T_ab888_row11_col3, #T_ab888_row20_col3, #T_ab888_row22_col3, #T_ab888_row23_col13, #T_ab888_row25_col3, #T_ab888_row25_col13, #T_ab888_row27_col3, #T_ab888_row28_col3, #T_ab888_row28_col12 {
#   background-color: #cc4778;
#   color: #f1f1f1;
# }
# ...

# %%
nn.sample(30).style.background_gradient(cmap="inferno")
# Out:
# <style type="text/css">
# #T_dbf72_row0_col0, #T_dbf72_row12_col0, #T_dbf72_row26_col0 {
#   background-color: #d54a41;
#   color: #f1f1f1;
# }
# #T_dbf72_row0_col1, #T_dbf72_row5_col20, #T_dbf72_row14_col1, #T_dbf72_row15_col1 {
#   background-color: #721a6e;
#   color: #f1f1f1;
# }
# ...

# %%
nn.sample(30).style.background_gradient(cmap="magma")
# Out:
# <style type="text/css">
# #T_cc03e_row0_col0, #T_cc03e_row19_col0, #T_cc03e_row23_col0 {
#   background-color: #fde3a5;
#   color: #000000;
# }
# #T_cc03e_row0_col1, #T_cc03e_row23_col1, #T_cc03e_row29_col1 {
#   background-color: #fcecae;
#   color: #000000;
# }
# ...

# %%
nn.sample(30).style.background_gradient(cmap="Greens")
# Out:
# <style type="text/css">
# #T_32c57_row0_col0, #T_32c57_row14_col0, #T_32c57_row17_col0, #T_32c57_row26_col2, #T_32c57_row27_col0 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_32c57_row0_col1, #T_32c57_row2_col1, #T_32c57_row14_col1, #T_32c57_row17_col1, #T_32c57_row27_col1 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_32c57_row0_col2 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# ...

# %%
nn.sample(30).style.background_gradient(cmap="Oranges")
# Out:
# <style type="text/css">
# #T_7f573_row0_col0, #T_7f573_row6_col1 {
#   background-color: #c94202;
#   color: #f1f1f1;
# }
# #T_7f573_row0_col1, #T_7f573_row0_col13, #T_7f573_row1_col6, #T_7f573_row6_col13, #T_7f573_row6_col16, #T_7f573_row12_col16, #T_7f573_row13_col3, #T_7f573_row14_col3, #T_7f573_row15_col13, #T_7f573_row16_col3, #T_7f573_row18_col13, #T_7f573_row20_col3, #T_7f573_row20_col13, #T_7f573_row20_col16, #T_7f573_row21_col3, #T_7f573_row26_col13, #T_7f573_row27_col3, #T_7f573_row27_col13, #T_7f573_row29_col3 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_7f573_row0_col2, #T_7f573_row1_col0, #T_7f573_row6_col8, #T_7f573_row17_col8, #T_7f573_row20_col2, #T_7f573_row20_col8 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_7f573_row0_col3, #T_7f573_row1_col3, #T_7f573_row4_col10, #T_7f573_row5_col3, #T_7f573_row24_col3, #T_7f573_row25_col10 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# ...

# %%
nn.shape
# Out:
# (740, 21)

# %%
nn.dtypes
# Out:
# ID                                   int64
# Reason for absence                   int64
# Month of absence                     int64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense               int64
# Distance from Residence to Work      int64
# Service time                         int64
# Age                                  int64
# Work load Average/day              float64
# Hit target                           int64
# Disciplinary failure                 int64
# Education                            int64
# Son                                  int64
# Social drinker                       int64
# Social smoker                        int64
# Pet                                  int64
# Weight                               int64
# Height                               int64
# Body mass index                      int64
# Absenteeism time in hours            int64
# dtype: object

# %%
nn.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
nn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    float64
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
nn.drop("ID",axis=1,inplace=True)
nn.shape
# Out:
# (740, 20)

# %%
nn.describe()
# Out:
#        Reason for absence  Month of absence  Day of the week     Seasons  \
# count          740.000000        740.000000       740.000000  740.000000
# mean            19.216216          6.324324         3.914865    2.544595
# std              8.433406          3.436287         1.421675    1.111831
# min              0.000000          0.000000         2.000000    1.000000
# 25%             13.000000          3.000000         3.000000    2.000000
# 50%             23.000000          6.000000         4.000000    3.000000
# 75%             26.000000          9.000000         5.000000    4.000000
# max             28.000000         12.000000         6.000000    4.000000
#
#        Transportation expense  Distance from Residence to Work  Service time  \
# count              740.000000                       740.000000    740.000000
# mean               221.329730                        29.631081     12.554054
# std                 66.952223                        14.836788      4.384873
# ...

# %%
nn.describe().style.background_gradient(cmap="Dark2_r")
# Out:
# <style type="text/css">
# #T_0fb81_row0_col0, #T_0fb81_row0_col1, #T_0fb81_row0_col2, #T_0fb81_row0_col3, #T_0fb81_row0_col4, #T_0fb81_row0_col5, #T_0fb81_row0_col6, #T_0fb81_row0_col7, #T_0fb81_row0_col8, #T_0fb81_row0_col9, #T_0fb81_row0_col10, #T_0fb81_row0_col11, #T_0fb81_row0_col12, #T_0fb81_row0_col13, #T_0fb81_row0_col14, #T_0fb81_row0_col15, #T_0fb81_row0_col16, #T_0fb81_row0_col17, #T_0fb81_row0_col18, #T_0fb81_row0_col19 {
#   background-color: #1b9e77;
#   color: #f1f1f1;
# }
# ...

# %%
nn.describe().style.background_gradient(cmap="Oranges")
# Out:
# <style type="text/css">
# #T_3903c_row0_col0, #T_3903c_row0_col1, #T_3903c_row0_col2, #T_3903c_row0_col3, #T_3903c_row0_col4, #T_3903c_row0_col5, #T_3903c_row0_col6, #T_3903c_row0_col7, #T_3903c_row0_col8, #T_3903c_row0_col9, #T_3903c_row0_col10, #T_3903c_row0_col11, #T_3903c_row0_col12, #T_3903c_row0_col13, #T_3903c_row0_col14, #T_3903c_row0_col15, #T_3903c_row0_col16, #T_3903c_row0_col17, #T_3903c_row0_col18, #T_3903c_row0_col19 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_3903c_row1_col0, #T_3903c_row4_col18 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_3903c_row1_col1, #T_3903c_row1_col19, #T_3903c_row2_col0, #T_3903c_row4_col6, #T_3903c_row5_col1, #T_3903c_row6_col19, #T_3903c_row7_col15 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# ...

# %%
nn["Month of absence"].value_counts()
# Out:
# 3     87
# 2     72
# 10    71
# 7     67
# 5     64
# 11    63
# 8     54
# 6     54
# 9     53
# 4     53
# 1     50
# 12    49
# 0      3
# Name: Month of absence, dtype: int64

# %%
nn["Month of absence"].replace(0,3,inplace=True)
nn["Month of absence"].value_counts()
# Out:
# 3     90
# 2     72
# 10    71
# 7     67
# 5     64
# 11    63
# 8     54
# 6     54
# 9     53
# 4     53
# 1     50
# 12    49
# Name: Month of absence, dtype: int64

# %%
nn.skew()
# Out:
# Reason for absence                -0.915312
# Month of absence                   0.081737
# Day of the week                    0.102440
# Seasons                           -0.038532
# Transportation expense             0.396189
# Distance from Residence to Work    0.312083
# Service time                      -0.004720
# Age                                0.697703
# Work load Average/day              0.961457
# Hit target                        -1.261708
# Disciplinary failure               3.952270
# Education                          2.108953
# Son                                1.086465
# Social drinker                    -0.273327
# Social smoker                      3.290333
# Pet                                2.735715
# Weight                             0.017001
# Height                             2.566060
# Body mass index                    0.305046
# Absenteeism time in hours          5.720728
# dtype: float64

# %%
sns.distplot(nn["Absenteeism time in hours"])
plt.show()  # positive skew

# %%
sns.distplot(nn["Hit target"])
plt.show()  # negative skew

# %%
sns.distplot(nn["Weight"])
plt.show()  # peak is at centre

# %%
sns.distplot(nn["Service time"])
plt.show()

# %%
nn["Seasons"].value_counts().plot(kind="bar")
plt.title("Absence in Different Seasons")
plt.xlabel("Seasons")
plt.ylabel("Frequency")
plt.show()

# %%
bar_colors=["Blue","Pink","Red","Orange"]
nn["Seasons"].value_counts().plot(kind="bar",color=bar_colors)
plt.title("Absence in Different Seasons")
plt.xlabel("Seasons")
plt.ylabel("Frequency")
plt.show()

# %%
bar_colors=["Green","Pink","Teal","Orange"]
nn["Education"].value_counts().plot(kind="bar",color=bar_colors)
plt.title("Absence - Education")
plt.xlabel("Level of Education")
plt.ylabel("Frequency")
plt.show()

# %%
bar_colors=["Aqua","Pink"]
nn["Social drinker"].value_counts().plot(kind="bar",color=bar_colors)
plt.title("Absence - Social Drinker")
plt.xlabel("Social Drinker")
plt.ylabel("Frequency")
plt.show()

# %%
bar_colors=["Pink","Violet"]
nn["Social smoker"].value_counts().plot(kind="bar",color=bar_colors)
plt.title("Absence - Social smoker")
plt.xlabel("Social smoker")
plt.ylabel("Frequency")
plt.show()

# %%
corr=nn.corr()
corr
# Out:
#                                  Reason for absence  Month of absence  \
# Reason for absence                         1.000000         -0.092395
# Month of absence                          -0.092395          1.000000
# Day of the week                            0.116319         -0.005512
# Seasons                                   -0.117925          0.408072
# Transportation expense                    -0.119381          0.135803
# Distance from Residence to Work            0.161831         -0.003498
# Service time                               0.048425         -0.062274
# Age                                       -0.078608          0.002624
# Work load Average/day                     -0.123472         -0.170867
# Hit target                                 0.088943         -0.462376
# Disciplinary failure                      -0.545054          0.107637
# Education                                 -0.047357         -0.068004
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x="Age",y="Absenteeism time in hours",data=nn)
plt.show()

# %%
plt.rcParams['figure.figsize']=(20,10)
sns.boxplot(x="Age",y="Absenteeism time in hours",data=nn)
plt.show()

# %%
sns.boxplot(x="Son",y="Absenteeism time in hours",data=nn)
plt.show()

# %% [markdown]
# ### Linear Regression Model

# %%
sns.pairplot(nn)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = nn.drop(['Absenteeism time in hours'],axis=1)
y = nn[['Absenteeism time in hours']]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)

# %%
model_lr=LinearRegression()
model_lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model_lr.score(X_train,y_train)
# Out:
# 0.16265091440527213

# %%
model_lr.score(X_test,y_test)
# Out:
# 0.08181174142125025

# %% [markdown]
# ### Polynomial Model

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
poly=PolynomialFeatures(degree=2,interaction_only=True)
X_train2=poly.fit_transform(X_train)
X_test2=poly.fit_transform(X_test)
poly_clf=linear_model.LinearRegression()
poly_clf.fit(X_train2,y_train)
# Out:
# LinearRegression()

# %%
print(poly_clf.score(X_train2,y_train))
# Out:
# 0.42925425246599846

# %%
print(poly_clf.score(X_test2,y_test))
# Out:
# -1.747170775674208

# %% [markdown]
# ### Support Vector Regression Model

# %%
from sklearn.svm import SVR
model_svr=SVR()

# %%
model_svr.fit(X_train,y_train)
# Out:
# SVR()

# %%
model_svr.score(X_train,y_train)
# Out:
# -0.05943593351574461

# %%
model_svr.score(X_test,y_test)
# Out:
# -0.07094561721014059

# %%
model_svr=SVR(kernel='linear')

# %%
model_svr.fit(X_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
model_svr.score(X_train,y_train)
# Out:
# 0.0428978358944242

# %%
model_svr.score(X_test,y_test)
# Out:
# 0.054224399646862875

# %%
model_svr=SVR(kernel='poly')

# %%
model_svr.fit(X_train,y_train)
# Out:
# SVR(kernel='poly')

# %%
model_svr.score(X_train,y_train)
# Out:
# -0.05620607787449905

# %%
model_svr.score(X_test,y_test)
# Out:
# -0.06519546489514405

# %%
model_svr=SVR(kernel='sigmoid')

# %%
model_svr.fit(X_train,y_train)
# Out:
# SVR(kernel='sigmoid')

# %%
model_svr.score(X_train,y_train)
# Out:
# -0.08139504573205936

# %%
model_svr.score(X_test,y_test)
# Out:
# -0.10562082502454828

# %% [markdown]
# ### Preprocessing Techniques

# %%
from scipy.stats import zscore

# %%
Xscaled=X.apply(zscore)

# %%
X_train,X_test,y_train,y_test=train_test_split(Xscaled,y,test_size=0.30,random_state=0)

# %%
model_lr1=LinearRegression()
model_lr1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model_lr1.score(X_train,y_train)
# Out:
# 0.16265091440527213

# %%
model_lr1.score(X_test,y_test)
# Out:
# 0.0818117414212508

# %%
model_svr1=SVR()
model_svr1.fit(X_train,y_train)
# Out:
# SVR()

# %%
model_svr1.score(X_train,y_train)
# Out:
# 0.03559908975669468

# %%
model_svr1.score(X_test,y_test)
# Out:
# 0.0285664247608044

# %%
poly=PolynomialFeatures(degree=2,interaction_only=True)
X_train3=poly.fit_transform(X_train)
X_test3=poly.fit_transform(X_test)
poly_clf1=linear_model.LinearRegression()
poly_clf1.fit(X_train3,y_train)
# Out:
# LinearRegression()

# %%
print(poly_clf1.score(X_train3,y_train))
# Out:
# 0.45577858138843286

# %%
print(poly_clf1.score(X_test3,y_test))
# Out:
# -4.8627726018394576e+22
